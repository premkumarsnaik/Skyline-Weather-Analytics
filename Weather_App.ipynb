# %% [markdown]
# <a href="https://colab.research.google.com/github/premkumarsnaik/Skyline-Weather-Analytics/blob/main/Weather_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the repository (Replace with your actual GitHub URL)
# !git clone https://github.com/premkumarsnaik/Skyline-Weather-Analytics.git

# 2. Move into the project directory
# %cd Skyline-Weather-Analytics

# 3. Install necessary libraries
# !pip install requests ipywidgets pandas -q

print("✅ Setup Complete. You are ready to run the app!")
# Out:
# Cloning into 'Skyline-Weather-Analytics'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 6), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 10.89 KiB | 10.89 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/Skyline-Weather-Analytics
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 42.2 MB/s eta 0:00:00
# ✅ Setup Complete. You are ready to run the app!

# %%
# Go to the repo directory and pull updates
# !git -C /content/Skyline-Weather-Analytics pull origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 1011 bytes | 1011.00 KiB/s, done.
# From https://github.com/premkumarsnaik/Skyline-Weather-Analytics
#  * branch            main       -> FETCH_HEAD
#    13897e8..3698a73  main       -> origin/main
# Updating 13897e8..3698a73
# Fast-forward
#  actual_code.py | 3 ++-
#  1 file changed, 2 insertions(+), 1 deletion(-)

# %%
# !grep "base_url" actual_code.py
# Out:
#         self.base_url = "https://api.openweathermap.org/data/2.5/weather"
#         response = requests.get(self.base_url, params=params)

# %%
import importlib
import actual_code

# This line is the key—it forces a refresh of the module
importlib.reload(actual_code)

from actual_code import SkylinePro

# Re-initialize with your key
app = SkylinePro("f1d352232060e1e6567121532c82af10")
app.run()
# Out:
# interactive(children=(Dropdown(description='Target City:', options=('Bengaluru', 'Dubai', 'London', 'Mumbai', …

# %%
import pandas as pd
df = pd.read_csv('weather_history.csv')
print(df.describe()) # This will give you a statistical summary of the weather you've fetched.
# Out:
#             Temp  Feels_Like   Humidity  Wind_Speed
# count   6.000000    6.000000   6.000000    6.000000
# mean   28.005000   28.948333  50.500000    6.111667
# std    11.117819   12.172195  21.116344    1.730565
# min    11.480000   10.350000  17.000000    3.600000
# 25%    21.250000   21.422500  43.000000    5.270000
# 50%    32.560000   33.730000  50.500000    5.915000
# 75%    32.882500   37.525000  62.500000    7.580000
# max    40.960000   39.770000  78.000000    8.050000
